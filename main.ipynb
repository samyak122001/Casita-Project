# %% [markdown]
# # Welcome to our very cool menu generator! :)

# %% [markdown]
# ignore the code sweetie, just press run lol

# %% [markdown]
# #### modules

# %%
# import modules
import nbimporter

# local imports
from generate_list import create_ingredient_list
from generate_excel import export_to_excel
from generate_html import export_to_html

# %% [markdown]
# ### YAY <3

# %%
ingredients_df, menu_df = create_ingredient_list()

# %%
menu_df
# Out:
#                                      Monday                           Tuesday  \
# Breakfast         Pericos con queso y toast                   Avena con fruta
# Lunch      Enchiladas de pollo + Salsa roja  Enchiladas de pollo + Salsa roja
# Snack              Fruta (manzana o banana)                     Protein shake
# Dinner        Quesadillas de tinga de pollo     Quesadillas de tinga de pollo
#
#                                                    Wednesday  \
# Breakfast                          Pericos con queso y toast
# Lunch      Lomo de cerdo al horno + Arroz con frijoles + ...
# Snack                               Fruta (manzana o banana)
# Dinner                                         Simple Recipe
#
#                                                     Thursday  \
# Breakfast                                    Avena con fruta
# Lunch      Lomo de cerdo al horno + Arroz con frijoles + ...
# Snack                                          Protein shake
# ...

# %%
ingredients_df
# Out:
#             ingredients   qty     unit
# 0               oatmeal     8    packs
# 1                 fruit    16    units
# 2        chicken breast  2000    grams
# 3                  rice   200    grams
# 4                 beans   150    grams
# 5                  kale     1    bunch
# 6        cesar dressing     6     tbsp
# 7                cheese   480    grams
# 8   tortillas de harina    24    units
# 9                  eggs    12    units
# 10                bread     6   slices
# 11                 milk  1500       ml
# 12       protein powder     6   scoops
# 13        refried beans   400    grams
# 14              lentils   250    grams
# 15            red onion     1    units
# 16               tomato     3  serving
# 17               garlic     5   cloves
# 18               ginger     1     knob
# 19             cilantro    31    bunch
# 20                flour   200    grams
# 21                water   100       ml
# 22            tortillas    10    units
# ...

# %%
export_to_excel(ingredients_df, menu_df, filename='menu_and_ingredients.xlsx')
# Out:
# Data saved to menu_and_ingredients.xlsx

# %%
# export_to_html('.')
